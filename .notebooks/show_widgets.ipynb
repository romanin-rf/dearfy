# %%
from rich.console import Console

console = Console()

# %%
import inspect
import dearpygui.dearpygui as dpg

dpg_methods_names = [
    attr for attr in dir(dpg) if inspect.isfunction(getattr(dpg, attr))
]

dpg_widget_methods_names = [
    'add_button',
    'add_checkbox',
    'add_clipper',
    'add_color_button',
    'add_colormap',
    'add_colormap_button',
    'add_combo',
    'add_date_picker',
    'add_image',
    'add_image_button',
    'add_listbox',
    'add_loading_indicator',
    'add_menu',
    'add_menu_bar',
    'add_menu_item',
    'add_node',
]


console.print(dpg_widget_methods_names)
# Out:
# [
#     'add_button',
#     'add_checkbox',
#     'add_clipper',
#     'add_color_button',
#     'add_colormap',
#     'add_colormap_button',
#     'add_combo',
#     'add_date_picker',
#     'add_image',
#     'add_image_button',
#     'add_listbox',
#     'add_loading_indicator',
#     'add_menu',
#     'add_menu_bar',
#     'add_menu_item',
#     'add_node'
# ]
